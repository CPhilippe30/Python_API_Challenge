# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as st
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Weather Data
url = "http://api.openweathermap.org/data/2.5/weather?"
units = ["imperial"]

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

weather_response = requests.get(query_url + city)
weather_weather_json = weather_response.json()
weather_weather_json
# Out:
# {'cod': 429,
#  'message': 'Your account is temporary blocked due to exceeding of requests limitation of your subscription type. Please choose the proper subscription http://openweathermap.org/price'}

# %%
print(requests.get(query_url + city))
# Out:
# <Response [200]>

# %%
# Get weather data
print("Beginning Data Retrival")
print("------------------------------")
set_count = 1
record_count = 1

# Loop through the list of cities and perform a request for data on each
weather_df = {"City":[],"Cloudiness":[],"Country":[],"Date":[],"Humidity":[],"Lat":[],"Lng":[],"Max Temp":[],"Wind Speed": []}
for city in cities:
    weather_response = requests.get(query_url + city)
    weather_response_json = weather_response.json()
    
    if w_response.status_code == 200:
        weather_df["City"].append(city)
        weather_df["Cloudiness"].append(weather_response_json['clouds']['all'])
        weather_df["Country"].append(weather_response_json['sys']['country'])
        weather_df["Date"].append(weather_response_json['dt'])
        weather_df["Humidity"].append(weather_response_json['main']['humidity'])
        weather_df["Lat"].append(weather_response_json['coord']['lat'])
        weather_df["Lng"].append(w_response_json['coord']['lon'])
        weather_df["Max Temp"].append(w_response_json['main']['temp_max'])
        weather_df["Wind Speed"].append(w_response_json['wind']['speed'])
        if record_count <= 50:
            print(f"Processing Record {record_count} of Set {set_count} | {city}")
            record_count += 1 
        else:
            record_count = 0
            set_count += 1
            print(f"Processing Record {record_count} of Set {set_count} | {city}")
            record_count += 1
    else:
        print("City not found. Skipping...")
print("-------------------------")
print("Data Retrieval Complete")
print("-------------------------")
# Out:
# Beginning Data Retrival
# ------------------------------
# Processing Record 1 of Set 1 | inhambane
# Processing Record 2 of Set 1 | caravelas
# Processing Record 3 of Set 1 | coihaique
# Processing Record 4 of Set 1 | georgetown
# Processing Record 5 of Set 1 | codrington
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | hirara
# Processing Record 8 of Set 1 | ulladulla
# Processing Record 9 of Set 1 | nanortalik
# Processing Record 10 of Set 1 | bredasdorp
# Processing Record 11 of Set 1 | provideniya
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | omsukchan
# Processing Record 14 of Set 1 | cidreira
# Processing Record 15 of Set 1 | san patricio
# Processing Record 16 of Set 1 | bobo dioulasso
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | altagracia de orituco
# Processing Record 20 of Set 1 | poum
# Processing Record 21 of Set 1 | cherskiy
# Processing Record 22 of Set 1 | new norfolk
# Processing Record 23 of Set 1 | college
# Processing Record 24 of Set 1 | arraial do cabo
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | vila franca do campo
# City not found. Skipping...
# Processing Record 28 of Set 1 | katsuura
# Processing Record 29 of Set 1 | morris
# Processing Record 30 of Set 1 | boddam
# Processing Record 31 of Set 1 | pitimbu
# City not found. Skipping...
# Processing Record 32 of Set 1 | klyuchevskiy
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | stokmarknes
# Processing Record 37 of Set 1 | muzhi
# Processing Record 38 of Set 1 | castro
# Processing Record 39 of Set 1 | nichinan
# Processing Record 40 of Set 1 | leningradskiy
# Processing Record 41 of Set 1 | gopalganj
# Processing Record 42 of Set 1 | nouakchott
# Processing Record 43 of Set 1 | san quintin
# Processing Record 44 of Set 1 | kungurtug
# Processing Record 45 of Set 1 | auki
# Processing Record 46 of Set 1 | avarua
# Processing Record 47 of Set 1 | aklavik
# Processing Record 48 of Set 1 | vaini
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of Set 1 | karabuk
# Processing Record 50 of Set 1 | eyl
# Processing Record 0 of Set 2 | carnarvon
# Processing Record 1 of Set 2 | faya
# Processing Record 2 of Set 2 | lucapa
# Processing Record 3 of Set 2 | airai
# Processing Record 4 of Set 2 | barrow
# Processing Record 5 of Set 2 | albany
# Processing Record 6 of Set 2 | atuona
# City not found. Skipping...
# Processing Record 7 of Set 2 | bubaque
# Processing Record 8 of Set 2 | batagay-alyta
# Processing Record 9 of Set 2 | visnes
# City not found. Skipping...
# Processing Record 10 of Set 2 | naze
# Processing Record 11 of Set 2 | vista hermosa
# Processing Record 12 of Set 2 | nemuro
# Processing Record 13 of Set 2 | torbay
# Processing Record 14 of Set 2 | souillac
# Processing Record 15 of Set 2 | lompoc
# Processing Record 16 of Set 2 | yelanskiy
# Processing Record 17 of Set 2 | jamestown
# Processing Record 18 of Set 2 | kavieng
# Processing Record 19 of Set 2 | vestmanna
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | tiznit
# Processing Record 22 of Set 2 | gambela
# Processing Record 23 of Set 2 | yellowknife
# Processing Record 24 of Set 2 | cape town
# Processing Record 25 of Set 2 | qaanaaq
# Processing Record 26 of Set 2 | bambous virieux
# Processing Record 27 of Set 2 | piazza armerina
# Processing Record 28 of Set 2 | port alfred
# Processing Record 29 of Set 2 | taoudenni
# Processing Record 30 of Set 2 | sao filipe
# Processing Record 31 of Set 2 | indramayu
# Processing Record 32 of Set 2 | chokurdakh
# Processing Record 33 of Set 2 | kamaishi
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | ko samui
# Processing Record 36 of Set 2 | vallenar
# Processing Record 37 of Set 2 | yazoo city
# Processing Record 38 of Set 2 | kedrovyy
# Processing Record 39 of Set 2 | vulturu
# Processing Record 40 of Set 2 | capao bonito
# Processing Record 41 of Set 2 | bato
# Processing Record 42 of Set 2 | bulawayo
# Processing Record 43 of Set 2 | bethel
# Processing Record 44 of Set 2 | upernavik
# Processing Record 45 of Set 2 | bowen
# Processing Record 46 of Set 2 | qasigiannguit
# Processing Record 47 of Set 2 | hermanus
# Processing Record 48 of Set 2 | hilo
# Processing Record 49 of Set 2 | dukat
# City not found. Skipping...
# Processing Record 50 of Set 2 | kahului
# Processing Record 0 of Set 3 | kano
# Processing Record 1 of Set 3 | ayna
# Processing Record 2 of Set 3 | diffa
# Processing Record 3 of Set 3 | san-pedro
# Processing Record 4 of Set 3 | geraldton
# Processing Record 5 of Set 3 | kavaratti
# Processing Record 6 of Set 3 | klaksvik
# Processing Record 7 of Set 3 | hofn
# Processing Record 8 of Set 3 | polunochnoye
# Processing Record 9 of Set 3 | bengkulu
# Processing Record 10 of Set 3 | lebu
# Processing Record 11 of Set 3 | pizarro
# Processing Record 12 of Set 3 | tasiilaq
# Processing Record 13 of Set 3 | faanui
# Processing Record 14 of Set 3 | nantucket
# Processing Record 15 of Set 3 | hervey bay
# Processing Record 16 of Set 3 | toktogul
# Processing Record 17 of Set 3 | kruisfontein
# Processing Record 18 of Set 3 | tuy hoa
# Processing Record 19 of Set 3 | alofi
# Processing Record 20 of Set 3 | sandur
# Processing Record 21 of Set 3 | saint-philippe
# Processing Record 22 of Set 3 | ketchikan
# Processing Record 23 of Set 3 | makakilo city
# Processing Record 24 of Set 3 | severo-yeniseyskiy
# Processing Record 25 of Set 3 | san cristobal
# City not found. Skipping...
# Processing Record 26 of Set 3 | hasaki
# Processing Record 27 of Set 3 | okhotsk
# Processing Record 28 of Set 3 | butaritari
# Processing Record 29 of Set 3 | saskylakh
# Processing Record 30 of Set 3 | jibuti
# Processing Record 31 of Set 3 | new bern
# Processing Record 32 of Set 3 | mackay
# Processing Record 33 of Set 3 | tuatapere
# Processing Record 34 of Set 3 | nikolskoye
# Processing Record 35 of Set 3 | constitucion
# Processing Record 36 of Set 3 | thompson
# Processing Record 37 of Set 3 | ancud
# Processing Record 38 of Set 3 | pevek
# City not found. Skipping...
# Processing Record 39 of Set 3 | kasongo-lunda
# Processing Record 40 of Set 3 | road town
# Processing Record 41 of Set 3 | aguimes
# Processing Record 42 of Set 3 | salalah
# Processing Record 43 of Set 3 | hovd
# Processing Record 44 of Set 3 | ribeira grande
# Processing Record 45 of Set 3 | muhos
# Processing Record 46 of Set 3 | omboue
# Processing Record 47 of Set 3 | moose factory
# Processing Record 48 of Set 3 | ilulissat
# Processing Record 49 of Set 3 | anderson
# Processing Record 50 of Set 3 | meiktila
# Processing Record 0 of Set 4 | karratha
# Processing Record 1 of Set 4 | igarka
# Processing Record 2 of Set 4 | morondava
# Processing Record 3 of Set 4 | luderitz
# Processing Record 4 of Set 4 | hithadhoo
# City not found. Skipping...
# Processing Record 5 of Set 4 | mahebourg
# Processing Record 6 of Set 4 | quatre cocos
# Processing Record 7 of Set 4 | kidal
# Processing Record 8 of Set 4 | ola
# Processing Record 9 of Set 4 | tura
# Processing Record 10 of Set 4 | norman wells
# Processing Record 11 of Set 4 | buraydah
# City not found. Skipping...
# Processing Record 12 of Set 4 | plymouth
# City not found. Skipping...
# Processing Record 13 of Set 4 | kristiinankaupunki
# Processing Record 14 of Set 4 | shalya
# Processing Record 15 of Set 4 | kajaani
# Processing Record 16 of Set 4 | atherton
# Processing Record 17 of Set 4 | boueni
# Processing Record 18 of Set 4 | beringovskiy
# Processing Record 19 of Set 4 | touros
# Processing Record 20 of Set 4 | athabasca
# Processing Record 21 of Set 4 | cabedelo
# Processing Record 22 of Set 4 | miri
# Processing Record 23 of Set 4 | prado
# Processing Record 24 of Set 4 | saint anthony
# Processing Record 25 of Set 4 | villa corzo
# Processing Record 26 of Set 4 | grebenskaya
# Processing Record 27 of Set 4 | la reforma
# Processing Record 28 of Set 4 | bathsheba
# Processing Record 29 of Set 4 | marystown
# Processing Record 30 of Set 4 | muriwai beach
# Processing Record 31 of Set 4 | mareeba
# Processing Record 32 of Set 4 | ponta do sol
# Processing Record 33 of Set 4 | tazovskiy
# Processing Record 34 of Set 4 | acapulco
# Processing Record 35 of Set 4 | yulara
# Processing Record 36 of Set 4 | dikson
# Processing Record 37 of Set 4 | roald
# Processing Record 38 of Set 4 | garowe
# Processing Record 39 of Set 4 | lazaro cardenas
# Processing Record 40 of Set 4 | swift current
# Processing Record 41 of Set 4 | grand gaube
# Processing Record 42 of Set 4 | riyadh
# City not found. Skipping...
# Processing Record 43 of Set 4 | lorengau
# Processing Record 44 of Set 4 | pasni
# Processing Record 45 of Set 4 | severo-kurilsk
# Processing Record 46 of Set 4 | taltal
# Processing Record 47 of Set 4 | inverell
# Processing Record 48 of Set 4 | asosa
# City not found. Skipping...
# Processing Record 49 of Set 4 | griffith
# Processing Record 50 of Set 4 | kodiak
# Processing Record 0 of Set 5 | kaitangata
# City not found. Skipping...
# Processing Record 1 of Set 5 | nizhniy kuranakh
# Processing Record 2 of Set 5 | mingyue
# Processing Record 3 of Set 5 | oranjestad
# Processing Record 4 of Set 5 | atar
# Processing Record 5 of Set 5 | ustikolina
# Processing Record 6 of Set 5 | northam
# Processing Record 7 of Set 5 | grindavik
# Processing Record 8 of Set 5 | beloha
# Processing Record 9 of Set 5 | santa cruz cabralia
# Processing Record 10 of Set 5 | praya
# Processing Record 11 of Set 5 | camacha
# Processing Record 12 of Set 5 | padang
# Processing Record 13 of Set 5 | chon daen
# Processing Record 14 of Set 5 | panaba
# Processing Record 15 of Set 5 | nioro
# Processing Record 16 of Set 5 | murgab
# Processing Record 17 of Set 5 | hami
# Processing Record 18 of Set 5 | half moon bay
# Processing Record 19 of Set 5 | ferrol
# Processing Record 20 of Set 5 | hobyo
# Processing Record 21 of Set 5 | lerwick
# Processing Record 22 of Set 5 | samarai
# Processing Record 23 of Set 5 | qaqortoq
# Processing Record 24 of Set 5 | buchanan
# Processing Record 25 of Set 5 | muswellbrook
# Processing Record 26 of Set 5 | vila velha
# Processing Record 27 of Set 5 | vila
# Processing Record 28 of Set 5 | amzya
# Processing Record 29 of Set 5 | raga
# Processing Record 30 of Set 5 | kapaa
# Processing Record 31 of Set 5 | bardsir
# Processing Record 32 of Set 5 | lengshuijiang
# Processing Record 33 of Set 5 | pietarsaari
# Processing Record 34 of Set 5 | general roca
# City not found. Skipping...
# Processing Record 35 of Set 5 | sao miguel do araguaia
# Processing Record 36 of Set 5 | mandera
# Processing Record 37 of Set 5 | saldanha
# City not found. Skipping...
# Processing Record 38 of Set 5 | manaul
# Processing Record 39 of Set 5 | golden
# Processing Record 40 of Set 5 | flinders
# Processing Record 41 of Set 5 | izumrud
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 5 | nipawin
# Processing Record 43 of Set 5 | port hardy
# Processing Record 44 of Set 5 | vao
# Processing Record 45 of Set 5 | katsina
# Processing Record 46 of Set 5 | ambilobe
# Processing Record 47 of Set 5 | burnie
# Processing Record 48 of Set 5 | anakapalle
# City not found. Skipping...
# Processing Record 49 of Set 5 | ossora
# Processing Record 50 of Set 5 | margate
# Processing Record 0 of Set 6 | swan hill
# Processing Record 1 of Set 6 | saint-augustin
# Processing Record 2 of Set 6 | takoradi
# Processing Record 3 of Set 6 | gamba
# Processing Record 4 of Set 6 | cabo san lucas
# Processing Record 5 of Set 6 | vicuna
# Processing Record 6 of Set 6 | khatanga
# Processing Record 7 of Set 6 | lupsa
# Processing Record 8 of Set 6 | zarubino
# Processing Record 9 of Set 6 | champerico
# Processing Record 10 of Set 6 | vardo
# Processing Record 11 of Set 6 | muros
# Processing Record 12 of Set 6 | kouango
# Processing Record 13 of Set 6 | esperance
# Processing Record 14 of Set 6 | ambulu
# Processing Record 15 of Set 6 | san policarpo
# Processing Record 16 of Set 6 | olafsvik
# Processing Record 17 of Set 6 | mopti
# Processing Record 18 of Set 6 | woodridge
# Processing Record 19 of Set 6 | manokwari
# Processing Record 20 of Set 6 | broome
# Processing Record 21 of Set 6 | saint-pierre
# Processing Record 22 of Set 6 | fortuna
# Processing Record 23 of Set 6 | la cruz
# City not found. Skipping...
# Processing Record 24 of Set 6 | emilio carranza
# Processing Record 25 of Set 6 | nizwa
# Processing Record 26 of Set 6 | walvis bay
# Processing Record 27 of Set 6 | parabel
# Processing Record 28 of Set 6 | te anau
# Processing Record 29 of Set 6 | lagoa
# Processing Record 30 of Set 6 | qui nhon
# Processing Record 31 of Set 6 | roura
# Processing Record 32 of Set 6 | holme
# Processing Record 33 of Set 6 | port elizabeth
# Processing Record 34 of Set 6 | bundaberg
# Processing Record 35 of Set 6 | makurdi
# City not found. Skipping...
# Processing Record 36 of Set 6 | lavrentiya
# Processing Record 37 of Set 6 | saint-georges
# Processing Record 38 of Set 6 | pochutla
# Processing Record 39 of Set 6 | ambunti
# Processing Record 40 of Set 6 | hualmay
# Processing Record 41 of Set 6 | dunedin
# Processing Record 42 of Set 6 | gat
# Processing Record 43 of Set 6 | marsa matruh
# Processing Record 44 of Set 6 | kulhudhuffushi
# Processing Record 45 of Set 6 | sakakah
# Processing Record 46 of Set 6 | baiyin
# Processing Record 47 of Set 6 | thinadhoo
# Processing Record 48 of Set 6 | quesnel
# Processing Record 49 of Set 6 | langsa
# Processing Record 50 of Set 6 | buala
# Processing Record 0 of Set 7 | remontnoye
# Processing Record 1 of Set 7 | saint george
# Processing Record 2 of Set 7 | brae
# Processing Record 3 of Set 7 | sola
# Processing Record 4 of Set 7 | ust-nera
# Processing Record 5 of Set 7 | rawson
# Processing Record 6 of Set 7 | hof
# Processing Record 7 of Set 7 | nanyang
# Processing Record 8 of Set 7 | sagua la grande
# Processing Record 9 of Set 7 | clyde river
# Processing Record 10 of Set 7 | chapleau
# Processing Record 11 of Set 7 | exeter
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 12 of Set 7 | kismayo
# Processing Record 13 of Set 7 | pueblo nuevo
# Processing Record 14 of Set 7 | atasu
# Processing Record 15 of Set 7 | santiago
# Processing Record 16 of Set 7 | pangnirtung
# Processing Record 17 of Set 7 | sarangani
# Processing Record 18 of Set 7 | fortuna foothills
# Processing Record 19 of Set 7 | kamenka
# Processing Record 20 of Set 7 | plettenberg bay
# Processing Record 21 of Set 7 | nhulunbuy
# Processing Record 22 of Set 7 | hailey
# Processing Record 23 of Set 7 | tougue
# City not found. Skipping...
# Processing Record 24 of Set 7 | dhule
# Processing Record 25 of Set 7 | galle
# Processing Record 26 of Set 7 | ondjiva
# Processing Record 27 of Set 7 | los llanos de aridane
# Processing Record 28 of Set 7 | san nicolas
# Processing Record 29 of Set 7 | crepy-en-valois
# Processing Record 30 of Set 7 | gunjur
# Processing Record 31 of Set 7 | kemalpasa
# Processing Record 32 of Set 7 | tiksi
# Processing Record 33 of Set 7 | gangawati
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 34 of Set 7 | shimoda
# Processing Record 35 of Set 7 | sterling
# Processing Record 36 of Set 7 | san clemente
# City not found. Skipping...
# Processing Record 37 of Set 7 | narsaq
# Processing Record 38 of Set 7 | ajdabiya
# Processing Record 39 of Set 7 | suez
# Processing Record 40 of Set 7 | sao jose da coroa grande
# Processing Record 41 of Set 7 | luau
# Processing Record 42 of Set 7 | manakara
# Processing Record 43 of Set 7 | honningsvag
# Processing Record 44 of Set 7 | sadiqabad
# Processing Record 45 of Set 7 | abha
# Processing Record 46 of Set 7 | balabac
# Processing Record 47 of Set 7 | imbituba
# Processing Record 48 of Set 7 | bontang
# City not found. Skipping...
# Processing Record 49 of Set 7 | malindi
# Processing Record 50 of Set 7 | choix
# Processing Record 0 of Set 8 | verkhnetulomskiy
# Processing Record 1 of Set 8 | lasa
# Processing Record 2 of Set 8 | vazante
# Processing Record 3 of Set 8 | solnechnyy
# Processing Record 4 of Set 8 | venice
# Processing Record 5 of Set 8 | saint-louis
# Processing Record 6 of Set 8 | longyearbyen
# Processing Record 7 of Set 8 | playa del carmen
# Processing Record 8 of Set 8 | oyama
# Processing Record 9 of Set 8 | talnakh
# Processing Record 10 of Set 8 | victoria
# Processing Record 11 of Set 8 | comodoro rivadavia
# Processing Record 12 of Set 8 | rockland
# Processing Record 13 of Set 8 | zhangjiakou
# Processing Record 14 of Set 8 | tsiroanomandidy
# Processing Record 15 of Set 8 | inuvik
# Processing Record 16 of Set 8 | klyuchi
# Processing Record 17 of Set 8 | rudbar
# Processing Record 18 of Set 8 | anadyr
# Processing Record 19 of Set 8 | umm kaddadah
# Processing Record 20 of Set 8 | tamalameque
# Processing Record 21 of Set 8 | high level
# Processing Record 22 of Set 8 | avera
# Processing Record 23 of Set 8 | ibra
# Processing Record 24 of Set 8 | chuy
# Processing Record 25 of Set 8 | marawi
# Processing Record 26 of Set 8 | ruwi
# Processing Record 27 of Set 8 | cockburn town
# Processing Record 28 of Set 8 | ternate
# Processing Record 29 of Set 8 | zyryanka
# Processing Record 30 of Set 8 | ostrovnoy
# Processing Record 31 of Set 8 | longido
# Processing Record 32 of Set 8 | bograd
# City not found. Skipping...
# Processing Record 33 of Set 8 | devils lake
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 34 of Set 8 | laguna
# City not found. Skipping...
# Processing Record 35 of Set 8 | iqaluit
# Processing Record 36 of Set 8 | deputatskiy
# Processing Record 37 of Set 8 | joensuu
# Processing Record 38 of Set 8 | mount gambier
# City not found. Skipping...
# Processing Record 39 of Set 8 | tomatlan
# Processing Record 40 of Set 8 | saint-joseph
# Processing Record 41 of Set 8 | placido de castro
# Processing Record 42 of Set 8 | dwarka
# Processing Record 43 of Set 8 | marsaxlokk
# Processing Record 44 of Set 8 | aswan
# Processing Record 45 of Set 8 | arlit
# Processing Record 46 of Set 8 | malabo
# Processing Record 47 of Set 8 | ullapool
# Processing Record 48 of Set 8 | pointe michel
# Processing Record 49 of Set 8 | bandarbeyla
# Processing Record 50 of Set 8 | gaoual
# Processing Record 0 of Set 9 | merauke
# Processing Record 1 of Set 9 | cap malheureux
# Processing Record 2 of Set 9 | puri
# Processing Record 3 of Set 9 | mount isa
# Processing Record 4 of Set 9 | regente feijo
# Processing Record 5 of Set 9 | henties bay
# Processing Record 6 of Set 9 | komsomolskiy
# Processing Record 7 of Set 9 | santa luzia
# Processing Record 8 of Set 9 | ipora
# Processing Record 9 of Set 9 | sumbe
# Processing Record 10 of Set 9 | waingapu
# Processing Record 11 of Set 9 | penzance
# Processing Record 12 of Set 9 | terre haute
# Processing Record 13 of Set 9 | hurghada
# Processing Record 14 of Set 9 | paamiut
# Processing Record 15 of Set 9 | puerto penasco
# Processing Record 16 of Set 9 | harrisonville
# Processing Record 17 of Set 9 | porbandar
# Processing Record 18 of Set 9 | camacupa
# City not found. Skipping...
# Processing Record 19 of Set 9 | alekseyevsk
# Processing Record 20 of Set 9 | pouembout
# Processing Record 21 of Set 9 | presidente olegario
# Processing Record 22 of Set 9 | pavlysh
# Processing Record 23 of Set 9 | belyy
# Processing Record 24 of Set 9 | luneville
# Processing Record 25 of Set 9 | emporia
# Processing Record 26 of Set 9 | garchitorena
# Processing Record 27 of Set 9 | zhigansk
# Processing Record 28 of Set 9 | mecca
# Processing Record 29 of Set 9 | tatishchevo
# Processing Record 30 of Set 9 | praia da vitoria
# Processing Record 31 of Set 9 | kijang
# Processing Record 32 of Set 9 | berlevag
# Processing Record 33 of Set 9 | bayir
# Processing Record 34 of Set 9 | privolzhye
# Processing Record 35 of Set 9 | sao felix do xingu
# Processing Record 36 of Set 9 | erdenet
# Processing Record 37 of Set 9 | fukue
# Processing Record 38 of Set 9 | ierapetra
# Processing Record 39 of Set 9 | cayenne
# Processing Record 40 of Set 9 | peterhead
# Processing Record 41 of Set 9 | warmbad
# Processing Record 42 of Set 9 | bontoc
# Processing Record 43 of Set 9 | biala podlaska
# Processing Record 44 of Set 9 | esil
# City not found. Skipping...
# Processing Record 45 of Set 9 | bonanza
# City not found. Skipping...
# Processing Record 46 of Set 9 | mozarlandia
# Processing Record 47 of Set 9 | kayerkan
# Processing Record 48 of Set 9 | ahipara
# Processing Record 49 of Set 9 | cordoba
# Processing Record 50 of Set 9 | isiolo
# Processing Record 0 of Set 10 | alice
# Processing Record 1 of Set 10 | olinda
# City not found. Skipping...
# Processing Record 2 of Set 10 | pangai
# Processing Record 3 of Set 10 | derzhavinsk
# Processing Record 4 of Set 10 | iracoubo
# Processing Record 5 of Set 10 | ulaangom
# Processing Record 6 of Set 10 | port hueneme
# Processing Record 7 of Set 10 | coquimbo
# Processing Record 8 of Set 10 | nieuw nickerie
# Processing Record 9 of Set 10 | westport
# Processing Record 10 of Set 10 | beyneu
# Processing Record 11 of Set 10 | fuengirola
# Processing Record 12 of Set 10 | ritchie
# Processing Record 13 of Set 10 | baykit
# Processing Record 14 of Set 10 | caraballeda
# Processing Record 15 of Set 10 | staryy nadym
# Processing Record 16 of Set 10 | muroto
# Processing Record 17 of Set 10 | santo antonio do ica
# Processing Record 18 of Set 10 | san lawrenz
# Processing Record 19 of Set 10 | novokruchininskiy
# Processing Record 20 of Set 10 | sorland
# Processing Record 21 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 10 | sumter
# Processing Record 23 of Set 10 | howard springs
# Processing Record 24 of Set 10 | suntar
# Processing Record 25 of Set 10 | brewster
# City not found. Skipping...
# Processing Record 26 of Set 10 | sevsk
# Processing Record 27 of Set 10 | medicine hat
# Processing Record 28 of Set 10 | teknaf
# Processing Record 29 of Set 10 | bourail
# Processing Record 30 of Set 10 | sambava
# Processing Record 31 of Set 10 | sitka
# City not found. Skipping...
# Processing Record 32 of Set 10 | sur

# %% [markdown]
# # Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Display DataFrame
weather_response=weather_response.replace('',np.nan).dropna(axis = 0, how = 'any')
weather_response.index.names = ["City ID"]
weather_response

# %%
# Export city data into a csv file

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
humidity_cities=weather_data[weather_data["Humidity"] > 100]
humidity_cities.head()

# %% [markdown]
# ## Plotting the Data
#
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build Scatter Plot for Each Data Type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], facecolors="pink", marker="o", edgecolor="black")

# Incorporate Other Graph Properties
plt.title("Latitude vs. Max Temperature Plot (04/20/2021)")
plt.ylabel("Max Temperature (°F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../Images/Latitude vs Max Temperature Plot.png")

# Show Plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build Scatter Plot for Each Data Type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], facecolors="red", marker="o", edgecolor="black")
# Incorporate Other Graph Properties
plt.title("Latitude vs. Humidity Plot (04/20/2021)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../Images/Latitude vs Humidity Plot.png")

# Show Plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build Scatter Plot for Each Data Type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], facecolors="blue", marker="o", edgecolor="black")

# Incorporate Other Graph Properties
plt.title("Latitude vs. Cloudiness Plot (04/20/2021)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../Images/City Latitude vs Cloudiness Plot.png")

# Show Plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build Scatter Plot for Each Data Type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], facecolors="yellow", marker="o", edgecolor="black")

# Incorporate Other Graph Properties
plt.title("Latitude vs. Wind Speed Plot (04/20/2021)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save Figure
plt.savefig("../Images/City Latitude vs Wind Speed Plot (mph).png")

# Show Plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_data.loc[weather_data["Lat"] >= 0]
southern_hemisphere = weather_data.loc[weather_data["Lat"] < 0]

# %%
# Define function for creating linear agression and scatter plot
def linear_agression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, 0, 0)

# Set a title
plt.title("Northern Hemisphere - Max Temperature vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temperature (F)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
