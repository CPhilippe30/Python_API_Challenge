# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as stats
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 631

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
index_counter = 0
set_counter = 1

# %%
print("Beginning Data Retrieval ")
print("-----------------------------")

url = "http://api.openweathermap.org/data/2.5/weather?"
units = ["imperial"]

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

        
print("Beginning Data Retrieval \n---------------------") 
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")
        time.sleep(1.01)

print("-----------------------------\nData Retrieval Complete ")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Beginning Data Retrieval
# ---------------------
# Processing Record 1 of Set 1 : butaritari
# Processing Record 2 of Set 1 : tuktoyaktuk
# Processing Record 3 of Set 1 : mar del plata
# Processing Record 4 of Set 1 : luganville
# Processing Record 5 of Set 1 : luderitz
# Processing Record 6 of Set 1 : virginia beach
# Processing Record 7 of Set 1 : gambela
# City not found. Skipping...
# Processing Record 8 of Set 1 : port lincoln
# Processing Record 9 of Set 1 : coahuayana
# Processing Record 10 of Set 1 : rikitea
# City not found. Skipping...
# Processing Record 11 of Set 1 : hilo
# Processing Record 12 of Set 1 : avarua
# Processing Record 13 of Set 1 : khed brahma
# Processing Record 14 of Set 1 : cherskiy
# Processing Record 15 of Set 1 : hay river
# Processing Record 16 of Set 1 : taoudenni
# City not found. Skipping...
# Processing Record 17 of Set 1 : salalah
# Processing Record 18 of Set 1 : chuy
# Processing Record 19 of Set 1 : kulhudhuffushi
# Processing Record 20 of Set 1 : russell
# Processing Record 21 of Set 1 : ilulissat
# Processing Record 22 of Set 1 : mariental
# Processing Record 23 of Set 1 : mataura
# Processing Record 24 of Set 1 : georgetown
# Processing Record 25 of Set 1 : qaanaaq
# Processing Record 26 of Set 1 : saint-pierre
# Processing Record 27 of Set 1 : hermanus
# Processing Record 28 of Set 1 : lebedyan
# Processing Record 29 of Set 1 : puerto ayora
# Processing Record 30 of Set 1 : walvis bay
# Processing Record 31 of Set 1 : yokadouma
# Processing Record 32 of Set 1 : busselton
# Processing Record 33 of Set 1 : saldanha
# Processing Record 34 of Set 1 : atuona
# Processing Record 35 of Set 1 : imbituba
# Processing Record 36 of Set 1 : tasiilaq
# City not found. Skipping...
# Processing Record 37 of Set 1 : westport
# Processing Record 38 of Set 1 : lerwick
# Processing Record 39 of Set 1 : port alfred
# City not found. Skipping...
# Processing Record 40 of Set 1 : aquiraz
# Processing Record 41 of Set 1 : nikolskoye
# Processing Record 42 of Set 1 : pierre
# Processing Record 43 of Set 1 : mutis
# Processing Record 44 of Set 1 : petrovsk-zabaykalskiy
# Processing Record 45 of Set 1 : punta arenas
# Processing Record 46 of Set 1 : alenquer
# Processing Record 47 of Set 1 : geraldton
# Processing Record 48 of Set 1 : lebu
# Processing Record 49 of Set 1 : basco
# Processing Record 50 of Set 1 : jalu
# Processing Record 0 of Set 2 : colares
# Processing Record 1 of Set 2 : atasu
# Processing Record 2 of Set 2 : faya
# Processing Record 3 of Set 2 : arraial do cabo
# Processing Record 4 of Set 2 : bonthe
# Processing Record 5 of Set 2 : albany
# Processing Record 6 of Set 2 : upernavik
# Processing Record 7 of Set 2 : mildura
# Processing Record 8 of Set 2 : coihaique
# Processing Record 9 of Set 2 : victoria
# Processing Record 10 of Set 2 : bonavista
# Processing Record 11 of Set 2 : vardo
# Processing Record 12 of Set 2 : tahta
# Processing Record 13 of Set 2 : daru
# Processing Record 14 of Set 2 : kapaa
# Processing Record 15 of Set 2 : cayenne
# Processing Record 16 of Set 2 : maneadero
# Processing Record 17 of Set 2 : chokurdakh
# City not found. Skipping...
# Processing Record 18 of Set 2 : makaha
# Processing Record 19 of Set 2 : ushuaia
# Processing Record 20 of Set 2 : raudeberg
# City not found. Skipping...
# Processing Record 21 of Set 2 : vostok
# Processing Record 22 of Set 2 : saint-philippe
# Processing Record 23 of Set 2 : wadi maliz
# Processing Record 24 of Set 2 : vaini
# Processing Record 25 of Set 2 : monrovia
# Processing Record 26 of Set 2 : omsukchan
# Processing Record 27 of Set 2 : kruisfontein
# Processing Record 28 of Set 2 : jitra
# City not found. Skipping...
# Processing Record 29 of Set 2 : bubaque
# Processing Record 30 of Set 2 : takapau
# Processing Record 31 of Set 2 : hobyo
# Processing Record 32 of Set 2 : new norfolk
# Processing Record 33 of Set 2 : saint-augustin
# Processing Record 34 of Set 2 : mareeba
# Processing Record 35 of Set 2 : riyadh
# Processing Record 36 of Set 2 : torbay
# City not found. Skipping...
# Processing Record 37 of Set 2 : beringovskiy
# Processing Record 38 of Set 2 : statesboro
# Processing Record 39 of Set 2 : barrow
# Processing Record 40 of Set 2 : bani walid
# Processing Record 41 of Set 2 : puerto santander
# Processing Record 42 of Set 2 : severo-kurilsk
# Processing Record 43 of Set 2 : cape town
# Processing Record 44 of Set 2 : ponta do sol
# Processing Record 45 of Set 2 : great falls
# Processing Record 46 of Set 2 : fairbanks
# Processing Record 47 of Set 2 : dikson
# Processing Record 48 of Set 2 : saint george
# Processing Record 49 of Set 2 : jamestown
# Processing Record 50 of Set 2 : rawson
# Processing Record 0 of Set 3 : ostrovnoy
# Processing Record 1 of Set 3 : oranjemund
# Processing Record 2 of Set 3 : narsaq
# Processing Record 3 of Set 3 : cabo san lucas
# Processing Record 4 of Set 3 : tarauaca
# Processing Record 5 of Set 3 : altay
# Processing Record 6 of Set 3 : vao
# Processing Record 7 of Set 3 : menzelinsk
# Processing Record 8 of Set 3 : ola
# Processing Record 9 of Set 3 : olga
# Processing Record 10 of Set 3 : bell ville
# Processing Record 11 of Set 3 : vila franca do campo
# Processing Record 12 of Set 3 : birin
# Processing Record 13 of Set 3 : port shepstone
# Processing Record 14 of Set 3 : henties bay
# Processing Record 15 of Set 3 : tres arroyos
# Processing Record 16 of Set 3 : kenai
# Processing Record 17 of Set 3 : san quintin
# Processing Record 18 of Set 3 : castro
# Processing Record 19 of Set 3 : idaho falls
# Processing Record 20 of Set 3 : nanakuli
# Processing Record 21 of Set 3 : carnarvon
# Processing Record 22 of Set 3 : porto velho
# Processing Record 23 of Set 3 : hobart
# Processing Record 24 of Set 3 : qaqortoq
# Processing Record 25 of Set 3 : lavrentiya
# Processing Record 26 of Set 3 : faanui
# City not found. Skipping...
# Processing Record 27 of Set 3 : norman wells
# Processing Record 28 of Set 3 : brigantine
# Processing Record 29 of Set 3 : luziania
# Processing Record 30 of Set 3 : yaan
# Processing Record 31 of Set 3 : codrington
# Processing Record 32 of Set 3 : yellowknife
# Processing Record 33 of Set 3 : korla
# City not found. Skipping...
# Processing Record 34 of Set 3 : ribeira grande
# Processing Record 35 of Set 3 : talnakh
# Processing Record 36 of Set 3 : richards bay
# Processing Record 37 of Set 3 : rehoboth
# Processing Record 38 of Set 3 : copiapo
# Processing Record 39 of Set 3 : jequie
# Processing Record 40 of Set 3 : sao paulo de olivenca
# Processing Record 41 of Set 3 : kaspiysk
# Processing Record 42 of Set 3 : hithadhoo
# City not found. Skipping...
# Processing Record 43 of Set 3 : litovko
# City not found. Skipping...
# Processing Record 44 of Set 3 : sorong
# Processing Record 45 of Set 3 : ginda
# Processing Record 46 of Set 3 : gold coast
# Processing Record 47 of Set 3 : emerald
# Processing Record 48 of Set 3 : bluff
# Processing Record 49 of Set 3 : eyl
# Processing Record 50 of Set 3 : gamba
# Processing Record 0 of Set 4 : careiro da varzea
# Processing Record 1 of Set 4 : cidreira
# Processing Record 2 of Set 4 : kapit
# Processing Record 3 of Set 4 : rio verde de mato grosso
# Processing Record 4 of Set 4 : agboville
# Processing Record 5 of Set 4 : knysna
# Processing Record 6 of Set 4 : mahebourg
# Processing Record 7 of Set 4 : nadlac
# Processing Record 8 of Set 4 : tiksi
# Processing Record 9 of Set 4 : tianpeng
# Processing Record 10 of Set 4 : mount gambier
# Processing Record 11 of Set 4 : coquimbo
# Processing Record 12 of Set 4 : igrim
# Processing Record 13 of Set 4 : kutum
# Processing Record 14 of Set 4 : vanimo
# Processing Record 15 of Set 4 : barentu
# Processing Record 16 of Set 4 : abu samrah
# Processing Record 17 of Set 4 : bamberg
# Processing Record 18 of Set 4 : saskylakh
# Processing Record 19 of Set 4 : hamilton
# Processing Record 20 of Set 4 : bredasdorp
# Processing Record 21 of Set 4 : san ramon
# Processing Record 22 of Set 4 : itamaraca
# Processing Record 23 of Set 4 : srandakan
# Processing Record 24 of Set 4 : hofn
# Processing Record 25 of Set 4 : vila velha
# Processing Record 26 of Set 4 : kaitangata
# City not found. Skipping...
# Processing Record 27 of Set 4 : port elizabeth
# City not found. Skipping...
# Processing Record 28 of Set 4 : kaka
# Processing Record 29 of Set 4 : cockburn town
# Processing Record 30 of Set 4 : khatanga
# Processing Record 31 of Set 4 : arona
# Processing Record 32 of Set 4 : mahibadhoo
# Processing Record 33 of Set 4 : esperance
# Processing Record 34 of Set 4 : formosa
# Processing Record 35 of Set 4 : port hedland
# Processing Record 36 of Set 4 : sabha
# Processing Record 37 of Set 4 : college
# Processing Record 38 of Set 4 : touros
# Processing Record 39 of Set 4 : tura
# Processing Record 40 of Set 4 : dehui
# Processing Record 41 of Set 4 : broome
# Processing Record 42 of Set 4 : shingu
# Processing Record 43 of Set 4 : jefferson city
# Processing Record 44 of Set 4 : seguela
# Processing Record 45 of Set 4 : san patricio
# Processing Record 46 of Set 4 : canutama
# Processing Record 47 of Set 4 : sao desiderio
# Processing Record 48 of Set 4 : san policarpo
# Processing Record 49 of Set 4 : pomabamba
# Processing Record 50 of Set 4 : rock sound
# Processing Record 0 of Set 5 : anadyr
# Processing Record 1 of Set 5 : lujan
# Processing Record 2 of Set 5 : goalpara
# City not found. Skipping...
# Processing Record 3 of Set 5 : itupiranga
# Processing Record 4 of Set 5 : haines junction
# Processing Record 5 of Set 5 : sedro-woolley
# Processing Record 6 of Set 5 : mananjary
# Processing Record 7 of Set 5 : baracoa
# Processing Record 8 of Set 5 : churapcha
# City not found. Skipping...
# Processing Record 9 of Set 5 : antananarivo
# Processing Record 10 of Set 5 : nishihara
# City not found. Skipping...
# Processing Record 11 of Set 5 : bikaner
# Processing Record 12 of Set 5 : asau
# Processing Record 13 of Set 5 : mazagao
# Processing Record 14 of Set 5 : namibe
# Processing Record 15 of Set 5 : bathsheba
# Processing Record 16 of Set 5 : portland
# Processing Record 17 of Set 5 : homer
# Processing Record 18 of Set 5 : atbasar
# Processing Record 19 of Set 5 : bud
# Processing Record 20 of Set 5 : east london
# Processing Record 21 of Set 5 : tezu
# Processing Record 22 of Set 5 : rapid valley
# Processing Record 23 of Set 5 : hualmay
# Processing Record 24 of Set 5 : comodoro rivadavia
# Processing Record 25 of Set 5 : najran
# Processing Record 26 of Set 5 : grand gaube
# Processing Record 27 of Set 5 : macheng
# Processing Record 28 of Set 5 : pemba
# Processing Record 29 of Set 5 : port-gentil
# Processing Record 30 of Set 5 : presidente epitacio
# Processing Record 31 of Set 5 : kutahya
# Processing Record 32 of Set 5 : soure
# Processing Record 33 of Set 5 : redmond
# Processing Record 34 of Set 5 : iquique
# Processing Record 35 of Set 5 : airai
# Processing Record 36 of Set 5 : whyalla
# Processing Record 37 of Set 5 : yamoussoukro
# Processing Record 38 of Set 5 : snezhnogorsk
# Processing Record 39 of Set 5 : panlaitan
# Processing Record 40 of Set 5 : moree
# City not found. Skipping...
# Processing Record 41 of Set 5 : thompson
# Processing Record 42 of Set 5 : sao filipe
# Processing Record 43 of Set 5 : finschhafen
# Processing Record 44 of Set 5 : san rafael del sur
# Processing Record 45 of Set 5 : fortuna
# Processing Record 46 of Set 5 : chifeng
# Processing Record 47 of Set 5 : dingle
# Processing Record 48 of Set 5 : chase
# Processing Record 49 of Set 5 : port hardy
# Processing Record 50 of Set 5 : buluang
# City not found. Skipping...
# Processing Record 0 of Set 6 : ahuimanu
# Processing Record 1 of Set 6 : shilka
# Processing Record 2 of Set 6 : gobardanga
# Processing Record 3 of Set 6 : verkhoyansk
# Processing Record 4 of Set 6 : waipawa
# Processing Record 5 of Set 6 : upata
# Processing Record 6 of Set 6 : hazorasp
# Processing Record 7 of Set 6 : san luis
# Processing Record 8 of Set 6 : aykhal
# Processing Record 9 of Set 6 : suozhen
# Processing Record 10 of Set 6 : letlhakane
# Processing Record 11 of Set 6 : buala
# Processing Record 12 of Set 6 : balykshi
# Processing Record 13 of Set 6 : kiama
# Processing Record 14 of Set 6 : lamesa
# Processing Record 15 of Set 6 : penzance
# Processing Record 16 of Set 6 : andenes
# Processing Record 17 of Set 6 : laguna
# Processing Record 18 of Set 6 : starachowice
# Processing Record 19 of Set 6 : lazaro cardenas
# Processing Record 20 of Set 6 : nome
# Processing Record 21 of Set 6 : birao
# Processing Record 22 of Set 6 : contamana
# Processing Record 23 of Set 6 : broken hill
# Processing Record 24 of Set 6 : clyde river
# Processing Record 25 of Set 6 : balaipungut
# Processing Record 26 of Set 6 : port moresby
# Processing Record 27 of Set 6 : kirakira
# Processing Record 28 of Set 6 : bandarban
# Processing Record 29 of Set 6 : dali
# City not found. Skipping...
# Processing Record 30 of Set 6 : kavieng
# Processing Record 31 of Set 6 : carutapera
# Processing Record 32 of Set 6 : eenhana
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 6 : khandyga
# City not found. Skipping...
# Processing Record 34 of Set 6 : novogurovskiy
# Processing Record 35 of Set 6 : palmerston
# Processing Record 36 of Set 6 : mehamn
# Processing Record 37 of Set 6 : olafsvik
# Processing Record 38 of Set 6 : pevek
# Processing Record 39 of Set 6 : nokaneng
# City not found. Skipping...
# Processing Record 40 of Set 6 : neuquen
# Processing Record 41 of Set 6 : pangnirtung
# Processing Record 42 of Set 6 : provideniya
# Processing Record 43 of Set 6 : puro
# Processing Record 44 of Set 6 : kodiak
# Processing Record 45 of Set 6 : utete
# Processing Record 46 of Set 6 : marzuq
# Processing Record 47 of Set 6 : mitsamiouli
# Processing Record 48 of Set 6 : constitucion
# Processing Record 49 of Set 6 : kirkwall
# Processing Record 50 of Set 6 : alofi
# Processing Record 0 of Set 7 : tadine
# Processing Record 1 of Set 7 : christchurch
# City not found. Skipping...
# Processing Record 2 of Set 7 : aklavik
# Processing Record 3 of Set 7 : serebryansk
# City not found. Skipping...
# Processing Record 4 of Set 7 : murray bridge
# Processing Record 5 of Set 7 : kalabo
# Processing Record 6 of Set 7 : camacha
# Processing Record 7 of Set 7 : tupaciguara
# Processing Record 8 of Set 7 : marsa matruh
# Processing Record 9 of Set 7 : nanortalik
# Processing Record 10 of Set 7 : concarneau
# Processing Record 11 of Set 7 : tinglev
# Processing Record 12 of Set 7 : bac lieu
# Processing Record 13 of Set 7 : mindelo
# Processing Record 14 of Set 7 : traralgon
# Processing Record 15 of Set 7 : gofitskoye
# Processing Record 16 of Set 7 : pangoa
# Processing Record 17 of Set 7 : okato
# Processing Record 18 of Set 7 : sitka
# Processing Record 19 of Set 7 : dunedin
# City not found. Skipping...
# Processing Record 20 of Set 7 : hambantota
# Processing Record 21 of Set 7 : souillac
# Processing Record 22 of Set 7 : northam
# Processing Record 23 of Set 7 : mackay
# City not found. Skipping...
# Processing Record 24 of Set 7 : playa vicente
# City not found. Skipping...
# Processing Record 25 of Set 7 : nyurba
# Processing Record 26 of Set 7 : aurangabad
# Processing Record 27 of Set 7 : bengkulu
# Processing Record 28 of Set 7 : boa vista
# Processing Record 29 of Set 7 : matara
# Processing Record 30 of Set 7 : ingham
# Processing Record 31 of Set 7 : vila
# Processing Record 32 of Set 7 : serra talhada
# Processing Record 33 of Set 7 : komsomolskiy
# Processing Record 34 of Set 7 : port blair
# Processing Record 35 of Set 7 : naze
# Processing Record 36 of Set 7 : paita
# Processing Record 37 of Set 7 : tabory
# Processing Record 38 of Set 7 : lingyuan
# Processing Record 39 of Set 7 : jimenez
# Processing Record 40 of Set 7 : asfi
# Processing Record 41 of Set 7 : barguzin
# Processing Record 42 of Set 7 : avera
# City not found. Skipping...
# Processing Record 43 of Set 7 : hasaki
# Processing Record 44 of Set 7 : saint anthony
# Processing Record 45 of Set 7 : meulaboh
# City not found. Skipping...
# Processing Record 46 of Set 7 : luchegorsk
# Processing Record 47 of Set 7 : marmora
# Processing Record 48 of Set 7 : adiake
# Processing Record 49 of Set 7 : golspie
# Processing Record 50 of Set 7 : bollnas
# Processing Record 0 of Set 8 : kiunga
# Processing Record 1 of Set 8 : padang
# Processing Record 2 of Set 8 : wattegama
# Processing Record 3 of Set 8 : makarov
# Processing Record 4 of Set 8 : conceicao da barra
# Processing Record 5 of Set 8 : ancud
# Processing Record 6 of Set 8 : half moon bay
# Processing Record 7 of Set 8 : jinxiang
# Processing Record 8 of Set 8 : ambon
# Processing Record 9 of Set 8 : punta cardon
# Processing Record 10 of Set 8 : abu dhabi
# Processing Record 11 of Set 8 : khislavichi
# Processing Record 12 of Set 8 : babina
# Processing Record 13 of Set 8 : odesa
# Processing Record 14 of Set 8 : beroroha
# Processing Record 15 of Set 8 : meridian
# Processing Record 16 of Set 8 : leningradskiy
# Processing Record 17 of Set 8 : necochea
# Processing Record 18 of Set 8 : isiro
# Processing Record 19 of Set 8 : kahului
# Processing Record 20 of Set 8 : porto nacional
# Processing Record 21 of Set 8 : sao joao da barra
# Processing Record 22 of Set 8 : zherdevka
# Processing Record 23 of Set 8 : kabanjahe
# Processing Record 24 of Set 8 : marystown
# City not found. Skipping...
# Processing Record 25 of Set 8 : piopio
# Processing Record 26 of Set 8 : diapaga
# Processing Record 27 of Set 8 : portree
# Processing Record 28 of Set 8 : haputale
# City not found. Skipping...
# Processing Record 29 of Set 8 : marshall
# Processing Record 30 of Set 8 : flagstaff
# Processing Record 31 of Set 8 : sotouboua
# Processing Record 32 of Set 8 : belaya gora
# Processing Record 33 of Set 8 : khorixas
# Processing Record 34 of Set 8 : kungurtug
# Processing Record 35 of Set 8 : ndioum
# Processing Record 36 of Set 8 : kibondo
# Processing Record 37 of Set 8 : varnavino
# Processing Record 38 of Set 8 : klaksvik
# City not found. Skipping...
# Processing Record 39 of Set 8 : oyama
# Processing Record 40 of Set 8 : takoradi
# Processing Record 41 of Set 8 : itarema
# Processing Record 42 of Set 8 : gazojak
# Processing Record 43 of Set 8 : itoman
# Processing Record 44 of Set 8 : severo-yeniseyskiy
# Processing Record 45 of Set 8 : labuhan
# City not found. Skipping...
# Processing Record 46 of Set 8 : egvekinot
# Processing Record 47 of Set 8 : sosnovo-ozerskoye
# Processing Record 48 of Set 8 : peruibe
# Processing Record 49 of Set 8 : los llanos de aridane
# Processing Record 50 of Set 8 : fernie
# Processing Record 0 of Set 9 : ivanivka
# Processing Record 1 of Set 9 : moose factory
# Processing Record 2 of Set 9 : atar
# Processing Record 3 of Set 9 : koster
# Processing Record 4 of Set 9 : sikar
# Processing Record 5 of Set 9 : platon sanchez
# Processing Record 6 of Set 9 : grindavik
# Processing Record 7 of Set 9 : iguape
# Processing Record 8 of Set 9 : barranca
# City not found. Skipping...
# Processing Record 9 of Set 9 : ayagoz
# Processing Record 10 of Set 9 : pisco
# Processing Record 11 of Set 9 : mount isa
# Processing Record 12 of Set 9 : staryy nadym
# Processing Record 13 of Set 9 : washougal
# Processing Record 14 of Set 9 : santa maria
# Processing Record 15 of Set 9 : alpena
# Processing Record 16 of Set 9 : reconquista
# Processing Record 17 of Set 9 : voyvozh
# Processing Record 18 of Set 9 : porbandar
# Processing Record 19 of Set 9 : dolores
# Processing Record 20 of Set 9 : guerrero negro
# Processing Record 21 of Set 9 : casablanca
# Processing Record 22 of Set 9 : sam chuk
# Processing Record 23 of Set 9 : evensk
# Processing Record 24 of Set 9 : ladario
# Processing Record 25 of Set 9 : qitaihe
# Processing Record 26 of Set 9 : luanda
# City not found. Skipping...
# Processing Record 27 of Set 9 : tessalit
# City not found. Skipping...
# Processing Record 28 of Set 9 : port augusta
# Processing Record 29 of Set 9 : razdolnoye
# Processing Record 30 of Set 9 : sheltozero
# Processing Record 31 of Set 9 : margate
# Processing Record 32 of Set 9 : carmo do rio claro
# Processing Record 33 of Set 9 : namatanai
# Processing Record 34 of Set 9 : bayji
# Processing Record 35 of Set 9 : dwarka
# Processing Record 36 of Set 9 : saint-claude
# Processing Record 37 of Set 9 : glinka
# Processing Record 38 of Set 9 : trairi
# Processing Record 39 of Set 9 : dolinsk
# Processing Record 40 of Set 9 : kabompo
# Processing Record 41 of Set 9 : aberdeen
# Processing Record 42 of Set 9 : idrinskoye
# City not found. Skipping...
# Processing Record 43 of Set 9 : terney
# Processing Record 44 of Set 9 : manggar
# Processing Record 45 of Set 9 : lorengau
# Processing Record 46 of Set 9 : morristown
# Processing Record 47 of Set 9 : umea
# Processing Record 48 of Set 9 : san cristobal
# Processing Record 49 of Set 9 : baruun-urt
# Processing Record 50 of Set 9 : havre-saint-pierre
# Processing Record 0 of Set 10 : nabire
# Processing Record 1 of Set 10 : maymyo
# Processing Record 2 of Set 10 : pimentel
# Processing Record 3 of Set 10 : fonte boa
# Processing Record 4 of Set 10 : flinders
# Processing Record 5 of Set 10 : nantucket
# Processing Record 6 of Set 10 : kaeo
# Processing Record 7 of Set 10 : bandarbeyla
# Processing Record 8 of Set 10 : whitehorse
# Processing Record 9 of Set 10 : dimapur
# Processing Record 10 of Set 10 : tuatapere
# Processing Record 11 of Set 10 : ylivieska
# Processing Record 12 of Set 10 : mayo
# Processing Record 13 of Set 10 : isangel
# Processing Record 14 of Set 10 : rafraf
# Processing Record 15 of Set 10 : martinsville
# Processing Record 16 of Set 10 : lilongwe
# Processing Record 17 of Set 10 : beloslav
# Processing Record 18 of Set 10 : noumea
# Processing Record 19 of Set 10 : katubao
# Processing Record 20 of Set 10 : kloulklubed
# Processing Record 21 of Set 10 : waingapu
# Processing Record 22 of Set 10 : nhulunbuy
# Processing Record 23 of Set 10 : narrabri
# Processing Record 24 of Set 10 : ambatofinandrahana
# Processing Record 25 of Set 10 : pokhara
# Processing Record 26 of Set 10 : galle
# Processing Record 27 of Set 10 : samandag
# Processing Record 28 of Set 10 : teguldet
# Processing Record 29 of Set 10 : batagay-alyta
# Processing Record 30 of Set 10 : lake cowichan
# Processing Record 31 of Set 10 : khovu-aksy
# Processing Record 32 of Set 10 : shiyan
# Processing Record 33 of Set 10 : karratha
# Processing Record 34 of Set 10 : san rafael
# Processing Record 35 of Set 10 : armidale
# Processing Record 36 of Set 10 : makakilo city
# Processing Record 37 of Set 10 : hovd
# Processing Record 38 of Set 10 : kaspiyskiy
# City not found. Skipping...
# Processing Record 39 of Set 10 : koumac
# Processing Record 40 of Set 10 : abalak
# Processing Record 41 of Set 10 : balma
# Processing Record 42 of Set 10 : blind river
# Processing Record 43 of Set 10 : alice springs
# Processing Record 44 of Set 10 : ayan
# Processing Record 45 of Set 10 : mecca
# Processing Record 46 of Set 10 : marienburg
# Processing Record 47 of Set 10 : kysyl-syr
# Processing Record 48 of Set 10 : talara
# Processing Record 49 of Set 10 : rodrigues alves
# Processing Record 50 of Set 10 : largo
# Processing Record 0 of Set 11 : liliani
# Processing Record 1 of Set 11 : vestmannaeyjar
# Processing Record 2 of Set 11 : lidzbark warminski
# Processing Record 3 of Set 11 : kailua
# Processing Record 4 of Set 11 : kaili
# Processing Record 5 of Set 11 : manyana
# Processing Record 6 of Set 11 : sampit
# Processing Record 7 of Set 11 : nenjiang
# Processing Record 8 of Set 11 : sioux lookout
# Processing Record 9 of Set 11 : sur
# Processing Record 10 of Set 11 : keetmanshoop
# Processing Record 11 of Set 11 : nouadhibou
# Processing Record 12 of Set 11 : paris
# Processing Record 13 of Set 11 : cairns
# Processing Record 14 of Set 11 : launceston
# Processing Record 15 of Set 11 : presidencia roque saenz pena
# Processing Record 16 of Set 11 : rio grande
# Processing Record 17 of Set 11 : palmer
# Processing Record 18 of Set 11 : oxelosund
# Processing Record 19 of Set 11 : kununurra
# Processing Record 20 of Set 11 : shenjiamen
# Processing Record 21 of Set 11 : saint-paul
# Processing Record 22 of Set 11 : gobabis
# Processing Record 23 of Set 11 : rantepao
# Processing Record 24 of Set 11 : lata
# City not found. Skipping...
# Processing Record 25 of Set 11 : kamenka
# Processing Record 26 of Set 11 : taseyevo
# Processing Record 27 of Set 11 : oriximina
# City not found. Skipping...
# Processing Record 28 of Set 11 : seoul
# Processing Record 29 of Set 11 : togur
# Processing Record 30 of Set 11 : tual
# Processing Record 31 of Set 11 : solano
# City not found. Skipping...
# Processing Record 32 of Set 11 : albury
# Processing Record 33 of Set 11 : nizwa
# Processing Record 34 of Set 11 : visby
# Processing Record 35 of Set 11 : bethel
# Processing Record 36 of Set 11 : providencia
# Processing Record 37 of Set 11 : chavantes
# Processing Record 38 of Set 11 : severodvinsk
# Processing Record 39 of Set 11 : san lorenzo
# Processing Record 40 of Set 11 : bolshaya rechka
# Processing Record 41 of Set 11 : quimper
# Processing Record 42 of Set 11 : dale
# Processing Record 43 of Set 11 : constantine
# Processing Record 44 of Set 11 : muros
# Processing Record 45 of Set 11 : kuytun
# Processing Record 46 of Set 11 : mahon
# Processing Record 47 of Set 11 : kudahuvadhoo
# Processing Record 48 of Set 11 : vikhorevka
# Processing Record 49 of Set 11 : ilheus
# Processing Record 50 of Set 11 : erice
# Processing Record 0 of Set 12 : nurota
# Processing Record 1 of Set 12 : bay roberts
# Processing Record 2 of Set 12 : aitape
# Processing Record 3 of Set 12 : akdepe
# City not found. Skipping...
# Processing Record 4 of Set 12 : lompoc
# Processing Record 5 of Set 12 : caravelas
# Processing Record 6 of Set 12 : polunochnoye
# Processing Record 7 of Set 12 : grand haven
# Processing Record 8 of Set 12 : naryan-mar
# City not found. Skipping...
# Processing Record 9 of Set 12 : ambilobe
# Processing Record 10 of Set 12 : lasa
# Processing Record 11 of Set 12 : veraval
# Processing Record 12 of Set 12 : lunenburg
# Processing Record 13 of Set 12 : grao mogol
# Processing Record 14 of Set 12 : yeppoon
# Processing Record 15 of Set 12 : kavaratti
# Processing Record 16 of Set 12 : port hawkesbury
# City not found. Skipping...
# Processing Record 17 of Set 12 : pyu
# Processing Record 18 of Set 12 : okha
# Processing Record 19 of Set 12 : sao domingos
# Processing Record 20 of Set 12 : samarai
# Processing Record 21 of Set 12 : smithers
# Processing Record 22 of Set 12 : beberibe
# -----------------------------
# Data Retrieval Complete

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a DataFrame from Cities, Latitude, Longitude, Temperature, Humidity, Cloudiness & Wind Speed
weather_dict = pd.DataFrame({ 
                "City" : city_name,
                "Cloudiness" : cloudiness,
                "Country" : country,
                "Date" : date,
                "Humidity" : humidity,
                "Lat" : lat,
                "Lng" : lng,
                "Max Temp" : max_temp,
                "Wind Speed" : wind_speed
})

weather_df = pd.DataFrame(weather_dict)
weather_df.head()
# Out:
#             City  Cloudiness Country        Date  Humidity      Lat       Lng  \
# 0     Butaritari          99      KI  1619282591        73   3.0707  172.7902
# 1    Tuktoyaktuk          75      CA  1619282131        79  69.4541 -133.0374
# 2  Mar del Plata          40      AR  1619282134        60 -38.0023  -57.5575
# 3     Luganville          89      VU  1619282591        86 -15.5333  167.1667
# 4       Lüderitz           1      NA  1619282591        79 -26.6481   15.1594
#
#    Max Temp  Wind Speed
# 0    301.01        4.14
# 1    265.15        2.06
# 2    293.15        7.20
# 3    299.41        2.72
# 4    290.97        2.91

# %%
# Exporting the city data into csv
weather_df.to_csv('weather_data.csv', encoding='utf-8', index=False)

# %%
weather_df.describe()
# Out:
#        Cloudiness          Date    Humidity         Lat         Lng  \
# count  583.000000  5.830000e+02  583.000000  583.000000  583.000000
# mean    52.936535  1.619283e+09   66.343053   17.379473   19.293091
# std     36.637226  2.294395e+02   23.847503   33.861859   92.487450
# min      0.000000  1.619282e+09    1.000000  -54.800000 -179.166700
# 25%     20.000000  1.619282e+09   50.000000  -12.424650  -59.583350
# 50%     55.000000  1.619283e+09   73.000000   21.426700   21.071300
# 75%     90.000000  1.619283e+09   85.500000   46.648600  101.223450
# max    100.000000  1.619283e+09  100.000000   77.484000  179.316700
#
#          Max Temp  Wind Speed
# count  583.000000  583.000000
# mean   290.112813    3.614494
# std     11.361137    2.435574
# min    247.030000    0.280000
# 25%    282.150000    1.875000
# 50%    292.510000    3.090000
# 75%    299.150000    4.860000
# max    314.150000   15.950000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#check if there are any cities with >100% humidity
cities_humidity = weather_df["Humidity"].describe(include = "all")
print("The max value for humidity is 100%, so there are no values > than 100%.")
cities_humidity
# Out:
# The max value for humidity is 100%, so there are no values > than 100%.
# count    583.000000
# mean      66.343053
# std       23.847503
# min        1.000000
# 25%       50.000000
# 50%       73.000000
# 75%       85.500000
# max      100.000000
# Name: Humidity, dtype: float64

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_cities=weather_df[weather_df["Humidity"] > 100]
humidity_cities.head()
# Out:
# Empty DataFrame
# Columns: [City, Cloudiness, Country, Date, Humidity, Lat, Lng, Max Temp, Wind Speed]
# Index: []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create Plot 
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], facecolors="pink", marker="o", edgecolor="black")

# Label plot and annotate the line equation
plt.title("Latitude vs. Max Temperature (04/20/2021)")
plt.ylabel("Max Temperature (°F)")
plt.xlabel("Latitude")

plt.grid()

# Save Figure
plt.savefig("../Images/Latitude vs Max Temperature.png")

# Show Plot
plt.show()

# %%
This plot demonstrate that the temperature changes based on the latitude in both directions from South and North of the equator

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create Plot
plt.scatter(weather_df["Lat"], weather_df["Humidity"], facecolors="red", marker="o", edgecolor="black")
# # Label plot and annotate the line equation
plt.title("Latitude vs. Humidity (04/20/2021)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()

# Save Figure
plt.savefig("../Images/Latitude vs Humidity.png")

# Show Plot
plt.show()

# %%
Humidity is fairly distributed throughout the plot, high humidity occurs for both cities found farther or near to the equator.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create Plot
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], facecolors="green", marker="o", edgecolor="black")

# Label plot and annotate the line equation
plt.title("Latitude vs. Cloudiness (04/20/2021)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()

# Save Figure
plt.savefig("../Images/City Latitude vs Cloudiness.png")

# Show Plot
plt.show()

# %%
The outcome of the of the scatter plot tell us that the data points is evenly spread out, and there is no difference in cloudiness when the cities farther or nearer to the equator.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create Plot
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], facecolors="yellow", marker="o", edgecolor="black")

# Label plot and annotate the line equation
plt.title("Latitude vs. Wind Speed (04/20/2021)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()

# Save Figure
plt.savefig("../Images/City Latitude vs Wind Speed (mph).png")

# Show Plot
plt.show()

# %%
The plot displayed the lower wind speed when the cities are closer to the equator, and surprisingly the wind speed increase for the cities farther from the equator.

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_df.loc[weather_df["Lat"] >= 0]
southern_hemisphere = weather_df.loc[weather_df["Lat"] < 0]
northern_hemisphere.head()
# Out:
#                City  Cloudiness Country        Date  Humidity      Lat  \
# 0        Butaritari          99      KI  1619282591        73   3.0707
# 1       Tuktoyaktuk          75      CA  1619282131        79  69.4541
# 5    Virginia Beach          90      US  1619282592        48  36.8529
# 6           Gambēla          96      ET  1619282592        76   8.2500
# 8  Coahuayana Viejo          40      MX  1619282134        32  18.7333
#
#         Lng  Max Temp  Wind Speed
# 0  172.7902    301.01        4.14
# 1 -133.0374    265.15        2.06
# 5  -75.9780    292.59        3.60
# 6   34.5833    297.35        2.42
# 8 -103.6833    301.15        2.53

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# latitudes for cities in the Northern Hemisphere - Max Temp vs. Latitude Linear Regression
latitude = northern_hemisphere["Lat"]
temperature = northern_hemisphere["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(latitude, temperature)

# Get regression values
regress_values = latitude * slope + intercept
    
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
# Create Plot
plt.figure(figsize=(9,5))
plt.title("Northern Hemisphere - Max Temp (%) vs. Latitude Linear Regression")
plt.scatter(latitude,temperature)
plt.plot(latitude,regress_values,"r-")

# Label plot and annotate the line equation  
plt.annotate(line_eq,(20,25),fontsize=20,color="red")

plt.xlabel("Latitude", fontsize =14)
plt.ylabel("Max Temperature", fontsize =14)


# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()

# Save Figure
plt.savefig("../Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression (mph).png")
# Out:
# The r-value is: 0.7347297023922587

# %%
The result from the plot showed the relationship between Latitude  vs Max Temperature. This result indicates that there is warmer temperature for the cities that found near to the equator. When you go farther from the equator temperature decrease.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Latitudes for cities in the Southern Hemisphere - Southern Hemisphere - Max Temp vs. Latitude Linear Regression
latitude = southern_hemisphere["Lat"]
temperature = southern_hemisphere["Max Temp"]


(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(latitude, temperature)

# Get regression values
regress_values = latitude * slope + intercept
    
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
# Create Plot
plt.figure(figsize=(9,5))
plt.title("Southern Hemisphere - Max Temp (%) vs. Latitude Linear Regression")
plt.scatter(latitude,temperature)
plt.plot(latitude,regress_values,"r-")

# Label plot and annotate the line equation  
plt.annotate(line_eq,(20,25),fontsize=20,color="red")

plt.xlabel("Latitude", fontsize =14)
plt.ylabel("Max Temperature", fontsize =14)


# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()

# Save Figure
plt.savefig("../Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression (mph).png")
# Out:
# The r-value is: 0.5716186650460451

# %%
The temperature in respect to the latitude is very similar to the one in northern hemisphere, the correlation is smaller. Cities located on the same latitude may experience differrent temperature. The data points are more spreadout than northern hemisphere. There’s still a positive correlation! Warmer temperature is closer to the equator.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# latitudes for cities in the Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
latitude = northern_hemisphere["Lat"]
temperature = northern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(latitude, temperature)

# Get regression values
regress_values = latitude * slope + intercept
    
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
# Create Plot
plt.figure(figsize=(9,5))
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.scatter(latitude,temperature)
plt.plot(latitude,regress_values,"r-")

# Label plot and annotate the line equation  
plt.annotate(line_eq,(15,25),fontsize=20,color="red")

plt.xlabel("Latitude", fontsize =14)
plt.ylabel("Humidity", fontsize =14)
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15);

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()

# Save Figure
plt.savefig("../Images/Northern Hemisphere - Humidity vs. Latitude Linear Regression (mph).png")
# Out:
# The r-value is: 0.03555230833465273

# %%
•The correlation between Humidity vs latitude linear regression in the northern hemisphere is low in the northern hemisphere. 
•There’s a greater concentration with the lowest humidity among the dataset are found between latitude 0 and 45.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# latitudes for cities in the Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
latitude = northern_hemisphere["Lat"]
temperature = northern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(latitude, temperature)

# Get regression values
regress_values = latitude * slope + intercept
    
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
# Create Plot
plt.figure(figsize=(9,5))
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.scatter(latitude,temperature)
plt.plot(latitude,regress_values,"r-")

# Label plot and annotate the line equation  
plt.annotate(line_eq,(15,25),fontsize=20,color="red")

plt.xlabel("Latitude", fontsize =14)
plt.ylabel("Humidity", fontsize =14)
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15);

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()

# Save Figure
plt.savefig("../Images/Southern Hemisphere - Humidity vs. Latitude Linear Regression (mph).png")
# Out:
# The r-value is: 0.03555230833465273

# %%
•The plot showed there’s a low correlation between humidity vs latitude in the southern hemisphere. 
•The correlation is lower because the distribution is similar to northern hemisphere.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# latitudes for cities in the Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
latitude = northern_hemisphere["Lat"]
temperature = northern_hemisphere["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(latitude, temperature)

# Get regression values
regress_values = latitude * slope + intercept
    
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
# Create Plot
plt.figure(figsize=(9,5))
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.scatter(latitude,temperature)
plt.plot(latitude,regress_values,"r-")

# Label plot and annotate the line equation  
plt.annotate(line_eq,(15,25),fontsize=20,color="red")

plt.xlabel("Latitude", fontsize =14)
plt.ylabel("Cloudiness", fontsize =14)
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15);

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()


# Save Figure
plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression (mph).png")
# Out:
# The r-value is: 0.027049730680079355

# %%
•The data is widely spread out, there is no correlation between cloudiness vs latitude in the northern hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# latitudes for cities in the Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
latitude = northern_hemisphere["Lat"]
temperature = northern_hemisphere["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(latitude, temperature)

# Get regression values
regress_values = latitude * slope + intercept
    
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
# Create Plot
plt.figure(figsize=(9,5))
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.scatter(latitude,temperature)
plt.plot(latitude,regress_values,"r-")

# Label plot and annotate the line equation  
plt.annotate(line_eq,(15,25),fontsize=20,color="red")

plt.xlabel("Latitude", fontsize =14)
plt.ylabel("Cloudiness", fontsize =14)
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15);

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()

# Save Figure
plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression (mph).png")
# Out:
# The r-value is: 0.027049730680079355

# %%
•The data is widely spread out, there is no correlation between cloudiness vs latitude in the southern hemisphere.
•The change in latitude doesn’t determined cloudiness

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# latitudes for cities in the Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
latitude = northern_hemisphere["Lat"]
temperature = northern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(latitude, temperature)

# Get regression values
regress_values = latitude * slope + intercept
    
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
# Create Plot
plt.figure(figsize=(9,5))
plt.title("Northern Hemisphere - Wind Speed (mph) (%) vs. Latitude Linear Regression")
plt.scatter(latitude,temperature)
plt.plot(latitude,regress_values,"r-")

# Label plot and annotate the line equation  
plt.annotate(line_eq,(15,25),fontsize=20,color="red")

plt.xlabel("Latitude", fontsize =14)
plt.ylabel("Wind Speed", fontsize =14)
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15);

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()

# Save Figure
plt.savefig("../Images/Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression (mph).png")
# Out:
# The r-value is: 0.001650815494142017

# %%
•There’s a weak correlation between wind speed(mph) vs latitude for northern hemisphere
•The change in latitude doesn’t determine wind speed

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# latitudes for cities in the Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
latitude = southern_hemisphere["Lat"]
temperature = southern_hemisphere["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(latitude, temperature)

# Get regression values
regress_values = latitude * slope + intercept
    
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
# Create Plot
plt.figure(figsize=(9,5))
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.scatter(latitude,temperature)
plt.plot(latitude,regress_values,"r-")

# Label plot and annotate the line equation  
plt.annotate(line_eq,(15,25),fontsize=20,color="red")

plt.xlabel("Latitude", fontsize =14)
plt.ylabel("Cloudiness", fontsize =14)
plt.xticks(fontsize= 15)
plt.yticks(fontsize= 15);

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Save Figure
plt.savefig("../Images/Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression (mph).png")
# Out:
# The r-value is: 0.00010216506432884957

# %%
•There’s no correlation between between wind speed(mph) vs latitude for southern hemisphere

# %%
Observation/Analysis:
1.Temperatures get hotter for cities that are near the equator. When we moved farther from the equator temperature decrease. Climate appears colder in the northern hemisphere.
2.The relationship between humidity and cloudiness of the cities nearer or father to the equator does not show any significant results. The plot showed there’s a weak correlation between humidity and latitude in both northern and southern hemisphere.
3.The results from the analysis between wind speed (mph) and latitude reveal that lower wind speed when the cities are closer to the equator, surprisingly wind speed increase for the cities who’s further from the equator.
