# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import scipy.stats as stats
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Weather Data
url = "http://api.openweathermap.org/data/2.5/weather?"
units = ["imperial"]

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
print(requests.get(query_url + city))
# Out:
# <Response [200]>

# %%
# Set Up Lists to Hold Reponse Info
city = []
country = []
date = []
latitude = []
longitude = []
max_temperature = []
humidity = []
cloudiness = []
wind_speed = []


# Get weather data
print("Beginning Data Retrival")
print("------------------------------")
set_count = 1
city_count = 1

# Loop through the list of cities and perform a request for data on each
weather_df = {"City":[],"Cloudiness":[],"Country":[],"Date":[],"Humidity":[],"Lat":[],"Lng":[],"Max Temp":[],"Wind Speed": []}
for city in cities:
    weather_response = requests.get(query_url + city)
    weather_response_json = weather_response.json()
    
    if weather_response.status_code == 200:
        weather_df["City"].append(city)
        weather_df["Cloudiness"].append(weather_response_json['clouds']['all'])
        weather_df["Country"].append(weather_response_json['sys']['country'])
        weather_df["Date"].append(weather_response_json['dt'])
        weather_df["Humidity"].append(weather_response_json['main']['humidity'])
        weather_df["Lat"].append(weather_response_json['coord']['lat'])
        weather_df["Lng"].append(weather_response_json['coord']['lon'])
        weather_df["Max Temp"].append(weather_response_json['main']['temp_max'])
        weather_df["Wind Speed"].append(weather_response_json['wind']['speed'])
        if city_count <= 200:
            print(f"Processing Record {city_count} of Set {set_count} | {city}")
            city_count += 1 
            time.sleep(1.01)


        else:
            city_count = 0
            set_count += 1
            print(f"Processing Record {city_count} of Set {set_count} | {city}")
            city_count += 1
            time.sleep(1.01)


    else:
        print("City not found. Skipping...")
        time.sleep(1.01)
print("-------------------------")
print("Data Retrieval Complete")
print("-------------------------")
# Out:
# Beginning Data Retrival
# ------------------------------
# Processing Record 1 of Set 1 | beringovskiy
# Processing Record 2 of Set 1 | kapaa
# Processing Record 3 of Set 1 | rikitea
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | maunabo
# Processing Record 6 of Set 1 | san vicente
# Processing Record 7 of Set 1 | barrow
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | kodiak
# Processing Record 11 of Set 1 | bethel
# Processing Record 12 of Set 1 | albany
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | upernavik
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | naze
# Processing Record 18 of Set 1 | vila velha
# Processing Record 19 of Set 1 | ilulissat
# Processing Record 20 of Set 1 | bayaguana
# Processing Record 21 of Set 1 | nantucket
# Processing Record 22 of Set 1 | sao joao da barra
# Processing Record 23 of Set 1 | ocos
# City not found. Skipping...
# Processing Record 24 of Set 1 | east london
# City not found. Skipping...
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | vaini
# Processing Record 27 of Set 1 | nuuk
# Processing Record 28 of Set 1 | palmer
# Processing Record 29 of Set 1 | provideniya
# Processing Record 30 of Set 1 | hamilton
# Processing Record 31 of Set 1 | mar del plata
# Processing Record 32 of Set 1 | dikson
# Processing Record 33 of Set 1 | magole
# Processing Record 34 of Set 1 | moose factory
# Processing Record 35 of Set 1 | sanghar
# Processing Record 36 of Set 1 | saskylakh
# Processing Record 37 of Set 1 | toora-khem
# Processing Record 38 of Set 1 | mananjary
# Processing Record 39 of Set 1 | mantua
# Processing Record 40 of Set 1 | georgetown
# Processing Record 41 of Set 1 | cherskiy
# Processing Record 42 of Set 1 | saint-leu
# Processing Record 43 of Set 1 | tunceli
# City not found. Skipping...
# Processing Record 44 of Set 1 | sitka
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 1 | krasnyy chikoy
# Processing Record 46 of Set 1 | avera
# Processing Record 47 of Set 1 | cabo san lucas
# Processing Record 48 of Set 1 | marzuq
# Processing Record 49 of Set 1 | pitogo
# Processing Record 50 of Set 1 | navirai
# Processing Record 51 of Set 1 | lasa
# Processing Record 52 of Set 1 | oistins
# City not found. Skipping...
# Processing Record 53 of Set 1 | thompson
# Processing Record 54 of Set 1 | codrington
# Processing Record 55 of Set 1 | hasaki
# Processing Record 56 of Set 1 | fortuna
# Processing Record 57 of Set 1 | butaritari
# Processing Record 58 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 59 of Set 1 | lazaro cardenas
# Processing Record 60 of Set 1 | requena
# Processing Record 61 of Set 1 | bredasdorp
# Processing Record 62 of Set 1 | te anau
# Processing Record 63 of Set 1 | belen
# Processing Record 64 of Set 1 | darmanesti
# Processing Record 65 of Set 1 | kutoarjo
# Processing Record 66 of Set 1 | shache
# Processing Record 67 of Set 1 | cape town
# Processing Record 68 of Set 1 | port macquarie
# Processing Record 69 of Set 1 | hilo
# Processing Record 70 of Set 1 | kihei
# Processing Record 71 of Set 1 | hithadhoo
# City not found. Skipping...
# Processing Record 72 of Set 1 | kamen-rybolov
# Processing Record 73 of Set 1 | busselton
# Processing Record 74 of Set 1 | matara
# Processing Record 75 of Set 1 | bartica
# Processing Record 76 of Set 1 | takoradi
# Processing Record 77 of Set 1 | bengkulu
# Processing Record 78 of Set 1 | zhicheng
# Processing Record 79 of Set 1 | chokurdakh
# Processing Record 80 of Set 1 | atar
# Processing Record 81 of Set 1 | camacha
# Processing Record 82 of Set 1 | verkhoyansk
# Processing Record 83 of Set 1 | luena
# Processing Record 84 of Set 1 | price
# Processing Record 85 of Set 1 | tasiilaq
# Processing Record 86 of Set 1 | geraldton
# City not found. Skipping...
# Processing Record 87 of Set 1 | new norfolk
# Processing Record 88 of Set 1 | saint-pierre
# Processing Record 89 of Set 1 | mogadishu
# City not found. Skipping...
# Processing Record 90 of Set 1 | dakar
# City not found. Skipping...
# Processing Record 91 of Set 1 | vaitape
# Processing Record 92 of Set 1 | airai
# Processing Record 93 of Set 1 | salinopolis
# Processing Record 94 of Set 1 | yining
# Processing Record 95 of Set 1 | kalmunai
# Processing Record 96 of Set 1 | vao
# Processing Record 97 of Set 1 | khatanga
# Processing Record 98 of Set 1 | poum
# Processing Record 99 of Set 1 | ewa beach
# Processing Record 100 of Set 1 | waipawa
# Processing Record 101 of Set 1 | nikolskoye
# City not found. Skipping...
# Processing Record 102 of Set 1 | pevek
# Processing Record 103 of Set 1 | poninka
# Processing Record 104 of Set 1 | moyo
# Processing Record 105 of Set 1 | mahebourg
# Processing Record 106 of Set 1 | xiaoweizhai
# Processing Record 107 of Set 1 | carnarvon
# Processing Record 108 of Set 1 | cidreira
# Processing Record 109 of Set 1 | san quintin
# Processing Record 110 of Set 1 | lorengau
# Processing Record 111 of Set 1 | zhaotong
# Processing Record 112 of Set 1 | faya
# Processing Record 113 of Set 1 | amahai
# Processing Record 114 of Set 1 | atuona
# Processing Record 115 of Set 1 | khorixas
# City not found. Skipping...
# Processing Record 116 of Set 1 | kununurra
# Processing Record 117 of Set 1 | half moon bay
# Processing Record 118 of Set 1 | saint-georges
# Processing Record 119 of Set 1 | santa maria
# Processing Record 120 of Set 1 | saint-philippe
# Processing Record 121 of Set 1 | quchan
# Processing Record 122 of Set 1 | san patricio
# Processing Record 123 of Set 1 | souillac
# Processing Record 124 of Set 1 | zlatibor
# Processing Record 125 of Set 1 | avarua
# Processing Record 126 of Set 1 | lima
# Processing Record 127 of Set 1 | aginskoye
# Processing Record 128 of Set 1 | deputatskiy
# Processing Record 129 of Set 1 | acarau
# Processing Record 130 of Set 1 | zittau
# Processing Record 131 of Set 1 | bluff
# Processing Record 132 of Set 1 | ada
# City not found. Skipping...
# Processing Record 133 of Set 1 | luderitz
# Processing Record 134 of Set 1 | ketchikan
# Processing Record 135 of Set 1 | yarim
# Processing Record 136 of Set 1 | catia la mar
# Processing Record 137 of Set 1 | hay river
# Processing Record 138 of Set 1 | esmeralda
# Processing Record 139 of Set 1 | carauari
# City not found. Skipping...
# Processing Record 140 of Set 1 | whitehorse
# Processing Record 141 of Set 1 | torbay
# Processing Record 142 of Set 1 | labuhan
# Processing Record 143 of Set 1 | isangel
# Processing Record 144 of Set 1 | hobart
# Processing Record 145 of Set 1 | nanzhang
# Processing Record 146 of Set 1 | port elizabeth
# Processing Record 147 of Set 1 | lebu
# Processing Record 148 of Set 1 | ukiah
# Processing Record 149 of Set 1 | castro
# Processing Record 150 of Set 1 | noumea
# Processing Record 151 of Set 1 | talnakh
# Processing Record 152 of Set 1 | lavrentiya
# City not found. Skipping...
# Processing Record 153 of Set 1 | otradnoye
# Processing Record 154 of Set 1 | manokwari
# Processing Record 155 of Set 1 | longyearbyen
# Processing Record 156 of Set 1 | buta
# Processing Record 157 of Set 1 | buyabod
# Processing Record 158 of Set 1 | ayan
# Processing Record 159 of Set 1 | asau
# Processing Record 160 of Set 1 | la ronge
# Processing Record 161 of Set 1 | el tigre
# City not found. Skipping...
# Processing Record 162 of Set 1 | rincon
# Processing Record 163 of Set 1 | sao filipe
# Processing Record 164 of Set 1 | lajedo
# Processing Record 165 of Set 1 | cravo norte
# Processing Record 166 of Set 1 | port alfred
# Processing Record 167 of Set 1 | boa vista
# Processing Record 168 of Set 1 | wonthaggi
# Processing Record 169 of Set 1 | cap malheureux
# Processing Record 170 of Set 1 | taltal
# Processing Record 171 of Set 1 | camana
# Processing Record 172 of Set 1 | ponta do sol
# Processing Record 173 of Set 1 | zhigansk
# Processing Record 174 of Set 1 | chernyshevskiy
# Processing Record 175 of Set 1 | laibin
# Processing Record 176 of Set 1 | pisco
# Processing Record 177 of Set 1 | muscat
# Processing Record 178 of Set 1 | shira
# Processing Record 179 of Set 1 | argayash
# Processing Record 180 of Set 1 | chegdomyn
# Processing Record 181 of Set 1 | sioux lookout
# City not found. Skipping...
# Processing Record 182 of Set 1 | santa marta
# Processing Record 183 of Set 1 | svetlogorsk
# City not found. Skipping...
# Processing Record 184 of Set 1 | nanortalik
# Processing Record 185 of Set 1 | bagdarin
# Processing Record 186 of Set 1 | hirara
# Processing Record 187 of Set 1 | bjornevatn
# Processing Record 188 of Set 1 | batangafo
# Processing Record 189 of Set 1 | victoria
# Processing Record 190 of Set 1 | norman wells
# Processing Record 191 of Set 1 | mahanoro
# Processing Record 192 of Set 1 | acacoyagua
# Processing Record 193 of Set 1 | bam
# Processing Record 194 of Set 1 | batemans bay
# Processing Record 195 of Set 1 | lompoc
# Processing Record 196 of Set 1 | erenhot
# City not found. Skipping...
# Processing Record 197 of Set 1 | baijiantan
# Processing Record 198 of Set 1 | tuatapere
# Processing Record 199 of Set 1 | marrakesh
# City not found. Skipping...
# Processing Record 200 of Set 1 | neiafu
# Processing Record 0 of Set 2 | nabire
# Processing Record 1 of Set 2 | port-de-bouc
# Processing Record 2 of Set 2 | tuktoyaktuk
# City not found. Skipping...
# Processing Record 3 of Set 2 | atambua
# Processing Record 4 of Set 2 | marawi
# Processing Record 5 of Set 2 | harindanga
# Processing Record 6 of Set 2 | andenes
# Processing Record 7 of Set 2 | young
# Processing Record 8 of Set 2 | roma
# Processing Record 9 of Set 2 | panaba
# Processing Record 10 of Set 2 | stornoway
# Processing Record 11 of Set 2 | qaanaaq
# City not found. Skipping...
# Processing Record 12 of Set 2 | faanui
# Processing Record 13 of Set 2 | vanavara
# City not found. Skipping...
# Processing Record 14 of Set 2 | nara
# Processing Record 15 of Set 2 | komsomolskiy
# Processing Record 16 of Set 2 | bundaberg
# Processing Record 17 of Set 2 | mount gambier
# Processing Record 18 of Set 2 | pozo colorado
# Processing Record 19 of Set 2 | tolaga bay
# Processing Record 20 of Set 2 | kaoma
# Processing Record 21 of Set 2 | muravlenko
# Processing Record 22 of Set 2 | finschhafen
# Processing Record 23 of Set 2 | vestmanna
# Processing Record 24 of Set 2 | monrovia
# Processing Record 25 of Set 2 | daru
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | clyde river
# Processing Record 28 of Set 2 | guayaramerin
# Processing Record 29 of Set 2 | bud
# Processing Record 30 of Set 2 | iqaluit
# Processing Record 31 of Set 2 | lagoa
# Processing Record 32 of Set 2 | abu kamal
# Processing Record 33 of Set 2 | dingle
# Processing Record 34 of Set 2 | minsk
# Processing Record 35 of Set 2 | tiksi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 36 of Set 2 | karaton
# Processing Record 37 of Set 2 | dwarka
# Processing Record 38 of Set 2 | jiexiu
# Processing Record 39 of Set 2 | coquimbo
# Processing Record 40 of Set 2 | sungaipenuh
# Processing Record 41 of Set 2 | san policarpo
# Processing Record 42 of Set 2 | kavieng
# Processing Record 43 of Set 2 | miles city
# Processing Record 44 of Set 2 | shenzhen
# Processing Record 45 of Set 2 | yueyang
# Processing Record 46 of Set 2 | husavik
# Processing Record 47 of Set 2 | padang
# Processing Record 48 of Set 2 | grindavik
# Processing Record 49 of Set 2 | cuicatlan
# Processing Record 50 of Set 2 | taoudenni
# City not found. Skipping...
# Processing Record 51 of Set 2 | balkhash
# Processing Record 52 of Set 2 | amapa
# Processing Record 53 of Set 2 | katsuura
# Processing Record 54 of Set 2 | puerto escondido
# Processing Record 55 of Set 2 | dibulla
# Processing Record 56 of Set 2 | comodoro rivadavia
# Processing Record 57 of Set 2 | bambous virieux
# Processing Record 58 of Set 2 | mount isa
# Processing Record 59 of Set 2 | khani
# Processing Record 60 of Set 2 | cayenne
# Processing Record 61 of Set 2 | joensuu
# Processing Record 62 of Set 2 | ocumare del tuy
# Processing Record 63 of Set 2 | dhidhdhoo
# Processing Record 64 of Set 2 | stephenville
# Processing Record 65 of Set 2 | kannad
# Processing Record 66 of Set 2 | tighina
# Processing Record 67 of Set 2 | port lincoln
# Processing Record 68 of Set 2 | goderich
# Processing Record 69 of Set 2 | oktyabrskiy
# Processing Record 70 of Set 2 | lamar
# Processing Record 71 of Set 2 | marsa matruh
# City not found. Skipping...
# Processing Record 72 of Set 2 | eskil
# Processing Record 73 of Set 2 | nenjiang
# Processing Record 74 of Set 2 | odesskoye
# Processing Record 75 of Set 2 | san jose
# Processing Record 76 of Set 2 | zhanakorgan
# Processing Record 77 of Set 2 | kimbe
# Processing Record 78 of Set 2 | puerto guzman
# Processing Record 79 of Set 2 | xam nua
# Processing Record 80 of Set 2 | jawar
# Processing Record 81 of Set 2 | cardoso
# Processing Record 82 of Set 2 | saldanha
# Processing Record 83 of Set 2 | muros
# Processing Record 84 of Set 2 | haapiti
# Processing Record 85 of Set 2 | nizwa
# Processing Record 86 of Set 2 | kurmanayevka
# Processing Record 87 of Set 2 | manggar
# City not found. Skipping...
# Processing Record 88 of Set 2 | salaya
# Processing Record 89 of Set 2 | erzin
# Processing Record 90 of Set 2 | turukhansk
# Processing Record 91 of Set 2 | talara
# Processing Record 92 of Set 2 | japura
# Processing Record 93 of Set 2 | abeche
# Processing Record 94 of Set 2 | guerrero negro
# Processing Record 95 of Set 2 | pontes e lacerda
# Processing Record 96 of Set 2 | vagur
# Processing Record 97 of Set 2 | aklavik
# Processing Record 98 of Set 2 | necochea
# Processing Record 99 of Set 2 | nowshera
# Processing Record 100 of Set 2 | sosnovo-ozerskoye
# Processing Record 101 of Set 2 | yellowknife
# Processing Record 102 of Set 2 | kruisfontein
# Processing Record 103 of Set 2 | garowe
# City not found. Skipping...
# Processing Record 104 of Set 2 | banska stiavnica
# Processing Record 105 of Set 2 | adrar
# Processing Record 106 of Set 2 | egvekinot
# Processing Record 107 of Set 2 | methoni
# Processing Record 108 of Set 2 | broken hill
# Processing Record 109 of Set 2 | pimentel
# Processing Record 110 of Set 2 | salym
# Processing Record 111 of Set 2 | yulara
# Processing Record 112 of Set 2 | salalah
# Processing Record 113 of Set 2 | velsk
# Processing Record 114 of Set 2 | anchorage
# Processing Record 115 of Set 2 | tomatlan
# Processing Record 116 of Set 2 | petatlan
# Processing Record 117 of Set 2 | puerto del rosario
# Processing Record 118 of Set 2 | guozhen
# Processing Record 119 of Set 2 | chuy
# Processing Record 120 of Set 2 | ahuimanu
# Processing Record 121 of Set 2 | leningradskiy
# Processing Record 122 of Set 2 | kaeo
# Processing Record 123 of Set 2 | sinnamary
# Processing Record 124 of Set 2 | kerrobert
# Processing Record 125 of Set 2 | raga
# Processing Record 126 of Set 2 | flinders
# Processing Record 127 of Set 2 | sorland
# Processing Record 128 of Set 2 | esperance
# Processing Record 129 of Set 2 | belmonte
# Processing Record 130 of Set 2 | jati
# Processing Record 131 of Set 2 | mega
# Processing Record 132 of Set 2 | tura
# Processing Record 133 of Set 2 | black river
# Processing Record 134 of Set 2 | kamenka
# Processing Record 135 of Set 2 | braganca
# Processing Record 136 of Set 2 | nikolayevsk-na-amure
# Processing Record 137 of Set 2 | udachnyy
# Processing Record 138 of Set 2 | urumqi

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a DataFrame from Cities, Latitude, Longitude, Temperature, Humidity, Cloudiness & Wind Speed
weather_dict = {
    "City": city,
    "Country": country,
    "Date": date,
    "Latitude": lat,
    "Longitude": lon,
    "Max Temperature": max_temp,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed
}

weather_df = pd.DataFrame(weather_dict)
weather_df.count()

# %%
# Exporting the city data into csv
weather_df.to_csv('weather_data.csv', encoding='utf-8', index=False)

# %%
weather_df.describe()

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#check if there are any cities with >100% humidity
cities_humidity = weather_df["Humidity"].describe(include = "all")
print("The max value for humidity is 100%, so there are no values > than 100%.")
cities_humidity

# %%
#  Get the indices of cities that have humidity over 100%.
humidity_cities=weather_df[weather_df["Humidity"] > 100]
humidity_cities.head()

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create Plot 
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], facecolors="pink", marker="o", edgecolor="black")

# Label plot and annotate the line equation
plt.title("Latitude vs. Max Temperature (04/20/2021)")
plt.ylabel("Max Temperature (°F)")
plt.xlabel("Latitude")
plt.grid()

# Save Figure
plt.savefig("../Images/Latitude vs Max Temperature.png")

# Show Plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create Plot
plt.scatter(weather_df["Lat"], weather_df["Humidity"], facecolors="red", marker="o", edgecolor="black")
# # Label plot and annotate the line equation
plt.title("Latitude vs. Humidity (04/20/2021)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()

# Save Figure
plt.savefig("../Images/Latitude vs Humidity.png")

# Show Plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create Plot
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], facecolors="green", marker="o", edgecolor="black")

# Label plot and annotate the line equation
plt.title("Latitude vs. Cloudiness (04/20/2021)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()

# Save Figure
plt.savefig("../Images/City Latitude vs Cloudiness.png")

# Show Plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create Plot
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], facecolors="yellow", marker="o", edgecolor="black")

# Label plot and annotate the line equation
plt.title("Latitude vs. Wind Speed (04/20/2021)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()

# Save Figure
plt.savefig("../Images/City Latitude vs Wind Speed (mph).png")

# Show Plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_df.loc[weather_df["Lat"] >= 0]
southern_hemisphere = weather_df.loc[weather_df["Lat"] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# latitudes for cities in the Northern Hemisphere - Max Temp vs. Latitude Linear Regression
latitude = northern_hemisphere["Lat"]
temperature = northern_hemisphere["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(latitude, temperature)

# Get regression values
regress_values = latitude * slope + intercept
    
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
# Create Plot
plt.figure(figsize=(9,5))
plt.title("Northern Hemisphere - Max Temp (%) vs. Latitude Linear Regression")
plt.scatter(latitude,temperature)
plt.plot(latitude,regress_values,"r-")

# Label plot and annotate the line equation    
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.annotate(line_eq,(20,15),fontsize=17,color="red")


# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()

# Save Figure
plt.savefig("../Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression (mph).png")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Latitudes for cities in the Northern Hemisphere - Southern Hemisphere - Max Temp vs. Latitude Linear Regression
latitude = southern_hemisphere["Lat"]
temperature = southern_hemisphere["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(latitude, temperature)

# Get regression values
regress_values = latitude * slope + intercept
    
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
# Create Plot
plt.figure(figsize=(9,5))
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.scatter(latitude,temperature)
plt.plot(latitude,regress_values,"r-")

# Label plot and annotate the line equation    
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.annotate(line_eq,(20,15),fontsize=17,color="red")


# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()

# Save Figure
plt.savefig("../Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression (mph).png")

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# latitudes for cities in the Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
latitude = northern_hemisphere["Lat"]
temperature = northern_hemisphere["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(latitude, temperature)

# Get regression values
regress_values = latitude * slope + intercept
    
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    
# Create Plot
plt.figure(figsize=(9,5))
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.scatter(latitude,temperature)
plt.plot(latitude,regress_values,"r-")

# Label plot and annotate the line equation    
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
plt.annotate(line_eq,(20,15),fontsize=17,color="red")


# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()

# Save Figure
plt.savefig("../Images/Northern Hemisphere - Humidity vs. Latitude Linear Regression (mph).png")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
